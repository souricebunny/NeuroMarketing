# %% [markdown]
# <a href="https://colab.research.google.com/github/souricebunny/NeuroMarketing/blob/main/surfexcelad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !uv pip install "tribev2[plotting] @ git+https://github.com/facebookresearch/tribev2.git"
# Out:
# Using Python 3.12.13 environment at: /usr
# Resolved 136 packages in 1.75s
# Prepared 44 packages in 1m 11s
# Uninstalled 22 packages in 828ms
# Installed 44 packages in 483ms
#  + cyclopts==4.20.0
#  - decorator==4.4.2
#  + decorator==5.3.1
#  + exca==0.5.20
#  + gtts==2.2.4
#  + julius==0.2.8
#  + langdetect==1.0.9
#  + levenshtein==0.27.3
#  + lightning-utilities==0.15.3
#  + mne==1.12.1
#  + mne-bids==0.19.0
#  - moviepy==1.0.3
#  + moviepy==2.2.1
#  + neuralset==0.0.2
#  + neuraltrain==0.0.2
#  + nilearn==0.14.0
#  - numpy==2.0.2
#  + numpy==2.2.6
#  - nvidia-cublas-cu12==12.8.4.1
#  + nvidia-cublas-cu12==12.4.5.8
#  - nvidia-cuda-cupti-cu12==12.8.90
#  + nvidia-cuda-cupti-cu12==12.4.127
#  - nvidia-cuda-nvrtc-cu12==12.8.93
#  + nvidia-cuda-nvrtc-cu12==12.4.127
#  - nvidia-cuda-runtime-cu12==12.8.90
#  + nvidia-cuda-runtime-cu12==12.4.127
#  - nvidia-cudnn-cu12==9.19.0.56
#  + nvidia-cudnn-cu12==9.1.0.70
#  - nvidia-cufft-cu12==11.3.3.83
#  + nvidia-cufft-cu12==11.2.1.3
# ...

# %%
# !pip install torchaudio==2.6.0 --force-reinstall --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 57.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 766.6/766.6 MB 697.4 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 70.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 38.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 51.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.1/150.1 MB 7.6 MB/s eta 0:00:00
# ...

# %%
from tribev2.demo_utils import TribeModel, download_file
from tribev2.plotting import PlotBrain
from pathlib import Path

CACHE_FOLDER = Path("./cache")

model = TribeModel.from_pretrained(
    "facebook/tribev2",
    cache_folder=CACHE_FOLDER,
)
plotter = PlotBrain(mesh="fsaverage5")
# Out:
# /usr/local/lib/python3.12/dist-packages/neuralset/extractors/base.py:707: UserWarning: LabelEncoder: event_types has not been set, are you sure you want to apply this extractor to all events?
#   warnings.warn(
# 2026-07-03 10:51:10 - WARNING - neuralset.extractors.base:798 - Missing events will be encoded using the default all-zero value (for example, 0 or a zero vector/tensor), which may be indistinguishable from a valid class if that class is also mapped to zeros. Set treat_missing_as_separate_class=True to avoid this.
# WARNING:neuralset.extractors.base:Missing events will be encoded using the default all-zero value (for example, 0 or a zero vector/tensor), which may be indistinguishable from a valid class if that class is also mapped to zeros. Set treat_missing_as_separate_class=True to avoid this.
# config.yaml:   0%|          | 0.00/18.0k [00:00<?, ?B/s]
# best.ckpt:   0%|          | 0.00/709M [00:00<?, ?B/s]
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0fb0a0bd-4535-450e-a033-132e73891fc4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0fb0a0bd-4535-450e-a033-132e73891fc4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
video_path = "/content/Surf Excel - Rs.10_- (30 sec) - PRIMARY COLOURS (360p, h264, youtube).mp4"

df = model.get_events_dataframe(video_path=video_path)
df = df[df['type'].isin(['Video', 'Audio'])].reset_index(drop=True)
df = df[df['start'] <= 10].reset_index(drop=True)

print(f"Total events: {len(df)}")
print(df['type'].value_counts())
display(df.head(8)[["type", "start", "duration"]])
# Out:
# Extract audio from video events:   0%|          | 0/1 [00:00<?, ?it/s]
# MoviePy - Writing audio in /content/Surf Excel - Rs.10_- (30 sec) - PRIMARY COLOURS (360p, h264, youtube).wav
# ...
# Extract audio from video events: 100%|██████████| 1/1 [00:00<00:00,  2.48it/s]
# /usr/local/lib/python3.12/dist-packages/neuralset/events/utils.py:134: UserWarning: The events dataframe contains an `Index` column. This is dangerous, please add drop=True in calls to df.reset_index(). Dropping it automatically.
#   warnings.warn(msg)
# MoviePy - Done.
# Extracting words from audio: 100%|██████████| 1/1 [03:23<00:00, 203.34s/it]
# /usr/local/lib/python3.12/dist-packages/neuralset/events/utils.py:134: UserWarning: The events dataframe contains an `Index` column. This is dangerous, please add drop=True in calls to df.reset_index(). Dropping it automatically.
#   warnings.warn(msg)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# ...

# %%
preds, segments = model.predict(events=df)
print(f"Predictions shape: {preds.shape}  (n_timesteps, n_vertices)")
# Out:
# [11:03:35 WARNING] Removing extractor text as there are no corresponding events
# WARNING:tribev2.main:Removing extractor text as there are no corresponding events
# [11:03:35 INFO] Preparing extractor: audio
# INFO:tribev2.main:Preparing extractor: audio
# preprocessor_config.json:   0%|          | 0.00/275 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.87k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.32G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/773 [00:00<?, ?it/s]
# [11:04:42 INFO] Preparing extractor: video
# INFO:tribev2.main:Preparing extractor: video
# config.json:   0%|          | 0.00/801 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/4.14G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/843 [00:00<?, ?it/s]
# video_preprocessor_config.json:   0%|          | 0.00/1.30k [00:00<?, ?B/s]
# 2026-07-03 11:07:51 - DEBUG - neuralset.extractors.video:277 - Loaded Video (duration 33.01s at 25.0fps, shape (640, 360)):
# ...

# %%
n_timesteps = 15
fig = plotter.plot_timesteps(preds[:n_timesteps], segments=segments[:n_timesteps], cmap="fire", norm_percentile=99, vmin=.6, alpha_cmap=(0, .2), show_stimuli=True)
# Out:
# Plotting...: 100%|██████████| 15/15 [00:04<00:00,  3.21it/s]
